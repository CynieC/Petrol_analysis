# %%
# import libraries
import pandas as pd

# %%
#load the data
df = pd.read_csv("Petrol_Dataset_July.csv", encoding = 'latin1')

# %%
#Find top 5 items in dataset
df.head()
# Out:
#    #        Country  Daily Oil Consumption (Barrels) World Share  \
# 0  1  United States                         19687287      20.30%
# 1  2          China                         12791553      13.20%
# 2  3          India                          4443000       4.60%
# 3  4          Japan                          4012877       4.10%
# 4  5         Russia                          3631287       3.70%
#
#    Yearly Gallons Per Capita  Price Per Gallon (USD)  Price Per Liter (USD)  \
# 0                      934.3                    5.19                   1.37
# 1                      138.7                    5.42                   1.43
# 2                       51.4                    5.05                   1.33
# 3                      481.5                    4.69                   1.24
# 4                      383.2                    3.41                   0.90
#
#    Price Per Liter (PKR)
# 0                 289.97
# 1                 302.87
# 2                 281.93
# ...

# %%
#Set index
df.set_index('#', inplace = True )

# %%
df.head()
# Out:
#          Country  Daily Oil Consumption (Barrels) World Share  \
# #
# 1  United States                         19687287      20.30%
# 2          China                         12791553      13.20%
# 3          India                          4443000       4.60%
# 4          Japan                          4012877       4.10%
# 5         Russia                          3631287       3.70%
#
#    Yearly Gallons Per Capita  Price Per Gallon (USD)  Price Per Liter (USD)  \
# #
# 1                      934.3                    5.19                   1.37
# 2                      138.7                    5.42                   1.43
# 3                       51.4                    5.05                   1.33
# 4                      481.5                    4.69                   1.24
# 5                      383.2                    3.41                   0.90
#
#    Price Per Liter (PKR)
# #
# 1                 289.97
# 2                 302.87
# 3                 281.93
# ...

# %%
#decribe the dataframe
df.describe()
# Out:
#        Daily Oil Consumption (Barrels)  Yearly Gallons Per Capita  \
# count                     1.810000e+02                 181.000000
# mean                      5.335730e+05                 332.006630
# std                       1.858067e+06                 436.558735
# min                       5.100000e+01                   2.200000
# 25%                       2.003600e+04                  53.900000
# 50%                       6.161200e+04                 180.200000
# 75%                       2.623520e+05                 424.600000
# max                       1.968729e+07                3679.500000
#
#        Price Per Gallon (USD)  Price Per Liter (USD)  Price Per Liter (PKR)
# count              181.000000             181.000000             181.000000
# mean                 5.695691               1.505138             318.219227
# std                  4.370484               1.154575             244.192081
# ...

# %%
#to find the data types
df.dtypes
# Out:
# Country                             object
# Daily Oil Consumption (Barrels)      int64
# World Share                         object
# Yearly Gallons Per Capita          float64
# Price Per Gallon (USD)             float64
# Price Per Liter (USD)              float64
# Price Per Liter (PKR)              float64
# dtype: object

# %%
#To check the columns in dataframe
df.columns
# Out:
# Index(['Country', 'Daily Oil Consumption (Barrels)', 'World Share',
#        'Yearly Gallons Per Capita', 'Price Per Gallon (USD)',
#        'Price Per Liter (USD)', 'Price Per Liter (PKR)'],
#       dtype='object')

# %%
#to identify null data
df.isna().sum()
# Out:
# Country                            0
# Daily Oil Consumption (Barrels)    0
# World Share                        0
# Yearly Gallons Per Capita          0
# Price Per Gallon (USD)             0
# Price Per Liter (USD)              0
# Price Per Liter (PKR)              0
# dtype: int64

# %%
df["World Share"].head(8)
# Out:
# #
# 1    20.30%
# 2    13.20%
# 3     4.60%
# 4     4.10%
# 5     3.70%
# 6     3.40%
# 7     3.10%
# 8     2.70%
# Name: World Share, dtype: object

# %%
df.Country
# Out:
# #
# 1                United States
# 2                        China
# 3                        India
# 4                        Japan
# 5                       Russia
#                 ...
# 177    Saint Pierre & Miquelon
# 178                   Kiribati
# 179                 Montserrat
# 180               Saint Helena
# 181                       Niue
# Name: Country, Length: 181, dtype: object

# %%
#information about dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 181 entries, 1 to 181
# Data columns (total 7 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          181 non-null    object
#  1   Daily Oil Consumption (Barrels)  181 non-null    int64
#  2   World Share                      181 non-null    object
#  3   Yearly Gallons Per Capita        181 non-null    float64
#  4   Price Per Gallon (USD)           181 non-null    float64
#  5   Price Per Liter (USD)            181 non-null    float64
#  6   Price Per Liter (PKR)            181 non-null    float64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 11.3+ KB

# %%
df[["Country", "World Share"]]
# Out:
#                      Country World Share
# #
# 1              United States      20.30%
# 2                      China      13.20%
# 3                      India       4.60%
# 4                      Japan       4.10%
# 5                     Russia       3.70%
# ..                       ...         ...
# 177  Saint Pierre & Miquelon       0.00%
# 178                 Kiribati       0.00%
# 179               Montserrat       0.00%
# 180             Saint Helena       0.00%
# 181                     Niue       0.00%
#
# [181 rows x 2 columns]

# %%
df[0:20:2]
# Out:
#            Country  Daily Oil Consumption (Barrels) World Share  \
# #
# 1    United States                         19687287      20.30%
# 3            India                          4443000       4.60%
# 5           Russia                          3631287       3.70%
# 7           Brazil                          2984000       3.10%
# 9           Canada                          2486301       2.60%
# 11          Mexico                          2052607       2.10%
# 13          France                          1705568       1.80%
# 15  United Kingdom                          1583896       1.60%
# 17        Thailand                          1302000       1.30%
# 19           Spain                          1290063       1.30%
#
#     Yearly Gallons Per Capita  Price Per Gallon (USD)  Price Per Liter (USD)  \
# #
# 1                       934.3                    5.19                   1.37
# 3                        51.4                    5.05                   1.33
# ...

# %%
df["Daily Oil Consumption (Barrels)"]
# Out:
# #
# 1      19687287
# 2      12791553
# 3       4443000
# 4       4012877
# 5       3631287
#          ...
# 177         660
# 178         400
# 179         400
# 180          70
# 181          51
# Name: Daily Oil Consumption (Barrels), Length: 181, dtype: int64

# %%
df.iloc[0,2]
# Out:
# '20.30%'

# %%
df.iloc[1:15, [0,3]]
# Out:
#            Country  Yearly Gallons Per Capita
# #
# 2            China                      138.7
# 3            India                       51.4
# 4            Japan                      481.5
# 5           Russia                      383.2
# 6     Saudi Arabia                     1560.2
# 7           Brazil                      221.9
# 8      South Korea                      783.4
# 9           Canada                     1047.6
# 10         Germany                      444.5
# 11          Mexico                      255.1
# 12            Iran                      347.6
# 13          France                      404.3
# 14       Indonesia                       95.1
# 15  United Kingdom                      366.2

# %%
df.iloc[1:10, [0,5]]
# Out:
#          Country  Price Per Liter (USD)
# #
# 2          China                   1.43
# 3          India                   1.33
# 4          Japan                   1.24
# 5         Russia                   0.90
# 6   Saudi Arabia                   0.62
# 7         Brazil                   1.42
# 8    South Korea                   1.61
# 9         Canada                   1.79
# 10       Germany                   2.02

# %%
#to set the cheap countries 
cheap= df[df["Price Per Gallon (USD)"] <5]

# %%
cheap
# Out:
#                     Country  Daily Oil Consumption (Barrels) World Share  \
# #
# 4                     Japan                          4012877       4.10%
# 5                    Russia                          3631287       3.70%
# 6              Saudi Arabia                          3302000       3.40%
# 11                   Mexico                          2052607       2.10%
# 12                     Iran                          1803999       1.90%
# ..                      ...                              ...         ...
# 173                Dominica                             1301       0.00%
# 174  British Virgin Islands                             1240       0.00%
# 175                 Vanuatu                             1100       0.00%
# 178                Kiribati                              400       0.00%
# 179              Montserrat                              400       0.00%
#
#      Yearly Gallons Per Capita  Price Per Gallon (USD)  Price Per Liter (USD)  \
# #
# ...

# %%
df[df["Price Per Gallon (USD)"] >5].shape
# Out:
# (106, 7)

# %%
expensive= df[(df["Price Per Gallon (USD)"] <5) & (df["Yearly Gallons Per Capita"] > 500)]

# %%
expensive
# Out:
#                     Country  Daily Oil Consumption (Barrels) World Share  \
# #
# 6              Saudi Arabia                          3302000       3.40%
# 22                   Taiwan                           981203       1.00%
# 26     United Arab Emirates                           896000       0.90%
# 41                   Kuwait                           359000       0.40%
# 61                    Libya                           223000       0.20%
# 66                     Oman                           183000       0.20%
# 67                    Qatar                           172000       0.20%
# 90                  Bahrain                            62000       0.06%
# 94      Trinidad and Tobago                            57000       0.06%
# 147                 Brunei                             16000       0.02%
# 174  British Virgin Islands                             1240       0.00%
# 179              Montserrat                              400       0.00%
#
# ...
